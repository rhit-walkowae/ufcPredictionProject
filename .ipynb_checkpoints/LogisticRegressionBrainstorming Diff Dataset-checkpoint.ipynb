# %%
## Exploring algorithms for UFC project
import pandas as pd
import os
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, RidgeCV , Lasso , LassoCV

# %%
path = os.getcwd()
p = path.removesuffix('ufcPredictionProject')
p = p+'UFCDiffdata.csv'


df = pd.read_csv(p)
df = df.drop(['Unnamed: 0'],axis = 1)
print(df.shape)
df.head(3)
# Out:
# (7780, 89)
#    DIFF_avg_KD  DIFF_avg_opp_KD  DIFF_avg_SIG_STR_pct  \
# 0          0.0         0.000000              0.200000
# 1          0.0        -0.960938             -0.238047
# 2         -0.5         0.625000              0.071250
#
#    DIFF_avg_opp_SIG_STR_pct  DIFF_avg_TD_pct  DIFF_avg_opp_TD_pct  \
# 0                 -0.010000         0.000000            -0.380000
# 1                 -0.092422         0.007031             0.134766
# 2                  0.031250         0.162500            -0.343750
#
#    DIFF_avg_SUB_ATT  DIFF_avg_opp_SUB_ATT  DIFF_avg_REV  DIFF_avg_opp_REV  \
# 0          1.000000                   0.0           1.0               1.0
# 1          0.007812                   0.0           0.0               0.0
# 2         -0.875000                   0.0           0.0               0.0
#
#    ...  weight_class_WomenStrawweight  Fighters_Stance_Open Stance  \
# 0  ...                              0                            0
# 1  ...                              0                            0
# 2  ...                              0                            0
#
#    Fighters_Stance_Orthodox  Fighters_Stance_Southpaw  Fighters_Stance_Switch  \
# 0                         0                         1                       0
# 1                         0                         1                       0
# 2                         0                         1                       0
#
#    Opponent_Stance_Open Stance  Opponent_Stance_Orthodox  \
# 0                            0                         0
# 1                            0                         0
# 2                            0                         0
#
#    Opponent_Stance_Southpaw  Opponent_Stance_Switch  Result
# 0                         1                       0    Loss
# 1                         1                       0    Loss
# 2                         1                       0     Win
#
# [3 rows x 89 columns]

# %%
df['weight_class_WomenStrawweight'].value_counts()
# Out:
# 0    7520
# 1     260
# Name: weight_class_WomenStrawweight, dtype: int64

# %%
# removing rows that contain NaN
df.dropna(inplace=True)
print(df.shape)
df.head(3)
print(df.isnull().sum().sum())
# Out:
# (7780, 89)
# 0

# %%
# test train split
(df_train,df_test) = train_test_split(df, train_size = 0.8)

X_train = df_train.drop('Result',axis=1)
y_train = df_train.Result

X_test = df_test.drop('Result',axis=1)
y_test = df_test.Result

X = X_train
y = y_train

print(X.isnull().sum().sum())
# Out:
# 0

# %%
X_train.head(3)
# Out:
#       DIFF_avg_KD  DIFF_avg_opp_KD  DIFF_avg_SIG_STR_pct  \
# 6452    -0.500000            0.000              0.047500
# 5590    -0.250000            0.250              0.123125
# 4384     0.087891           -0.125              0.015449
#
#       DIFF_avg_opp_SIG_STR_pct  DIFF_avg_TD_pct  DIFF_avg_opp_TD_pct  \
# 6452                  0.255000         0.000000             0.125000
# 5590                 -0.014687         0.137500            -0.412500
# 4384                  0.150254        -0.470273             0.726797
#
#       DIFF_avg_SUB_ATT  DIFF_avg_opp_SUB_ATT  DIFF_avg_REV  DIFF_avg_opp_REV  \
# 6452         -0.250000              0.000000           0.0             0.000
# 5590          0.187500              1.000000           0.0            -0.125
# 4384         -0.015625             -0.003906           0.0             0.000
#
#       ...  weight_class_WomenFlyweight  weight_class_WomenStrawweight  \
# 6452  ...                            0                              0
# 5590  ...                            0                              0
# 4384  ...                            0                              0
#
#       Fighters_Stance_Open Stance  Fighters_Stance_Orthodox  \
# 6452                            0                         0
# 5590                            0                         1
# 4384                            0                         1
#
#       Fighters_Stance_Southpaw  Fighters_Stance_Switch  \
# 6452                         1                       0
# 5590                         0                       0
# 4384                         0                       0
#
#       Opponent_Stance_Open Stance  Opponent_Stance_Orthodox  \
# 6452                            0                         1
# 5590                            0                         1
# 4384                            0                         1
#
#       Opponent_Stance_Southpaw  Opponent_Stance_Switch
# 6452                         0                       0
# 5590                         0                       0
# 4384                         0                       0
#
# [3 rows x 88 columns]

# %%
# split features into numerical and categorical
X_num = X.select_dtypes(include='number')
X_cat = X.select_dtypes(exclude='number')

# %%
# one hot encode
X_cat = pd.get_dummies(X_cat)
print(X_cat['title_bout'].value_counts())
X_cat.head(3)
# Out:
# False    5822
# True      402
# Name: title_bout, dtype: int64
#       title_bout
# 6452       False
# 5590       False
# 4384        True

# %%
# finding columns that are all zeros from X_num
cols = pd.Series(X_num.columns)
for i in range(len(cols)):
    if (X_num.iloc[:,i] == 0).all():
        print(cols[i])

# %%
# removing columns of zeros
#X_num = X_num.drop(['B_draw', 'R_draw'], axis=1)

# %%
# standardize
#X_num = (X_num - X_num.mean())/X_num.std()

# %%
# put back together
X = pd.concat([X_num,X_cat], axis=1)

# %%
print(X.shape)
X.head()
# Out:
# (6224, 88)
#       DIFF_avg_KD  DIFF_avg_opp_KD  DIFF_avg_SIG_STR_pct  \
# 6452    -0.500000         0.000000              0.047500
# 5590    -0.250000         0.250000              0.123125
# 4384     0.087891        -0.125000              0.015449
# 1126    -1.028015         0.002014             -0.114393
# 6195     0.000000         0.000000             -0.072500
#
#       DIFF_avg_opp_SIG_STR_pct  DIFF_avg_TD_pct  DIFF_avg_opp_TD_pct  \
# 6452                  0.255000         0.000000             0.125000
# 5590                 -0.014687         0.137500            -0.412500
# 4384                  0.150254        -0.470273             0.726797
# 1126                  0.311671         0.100912             0.306262
# 6195                 -0.245000         0.562500            -0.450000
#
#       DIFF_avg_SUB_ATT  DIFF_avg_opp_SUB_ATT  DIFF_avg_REV  DIFF_avg_opp_REV  \
# 6452         -0.250000              0.000000      0.000000           0.00000
# 5590          0.187500              1.000000      0.000000          -0.12500
# 4384         -0.015625             -0.003906      0.000000           0.00000
# 1126          2.390918              0.448772     -0.027342           0.03125
# 6195         -1.000000              0.000000      0.250000           0.00000
#
#       ...  weight_class_WomenStrawweight  Fighters_Stance_Open Stance  \
# 6452  ...                              0                            0
# 5590  ...                              0                            0
# 4384  ...                              0                            0
# 1126  ...                              0                            0
# 6195  ...                              0                            0
#
#       Fighters_Stance_Orthodox  Fighters_Stance_Southpaw  \
# 6452                         0                         1
# 5590                         1                         0
# 4384                         1                         0
# 1126                         0                         1
# 6195                         0                         1
#
#       Fighters_Stance_Switch  Opponent_Stance_Open Stance  \
# 6452                       0                            0
# 5590                       0                            0
# 4384                       0                            0
# 1126                       0                            0
# 6195                       0                            0
#
#       Opponent_Stance_Orthodox  Opponent_Stance_Southpaw  \
# 6452                         1                         0
# 5590                         1                         0
# 4384                         1                         0
# 1126                         0                         1
# 6195                         1                         0
#
#       Opponent_Stance_Switch  title_bout
# 6452                       0       False
# 5590                       0       False
# 4384                       0        True
# 1126                       0       False
# 6195                       0       False
#
# [5 rows x 88 columns]

# %%
y.value_counts()
# Out:
# Win     3080
# Loss    3034
# Draw     110
# Name: Result, dtype: int64

# %%
# logistic regression
logr = LogisticRegression(random_state=0, max_iter=10000)
logr.fit(X,y)
# Out:
# LogisticRegression(max_iter=10000, random_state=0)

# %%
# Training score
print('Training R2:',logr.score(X,y).round(2))
# Out:
# Training R2: 0.62

# %% [markdown]
# ## Finding Test Error

# %%
X_train = X
y_train = y

# %%
X = X_test
y = y_test

# %%
# split features into numerical and categorical
X_num = X.select_dtypes(include='number')
X_cat = X.select_dtypes(exclude='number')

# %%
# one hot encode
X_cat = pd.get_dummies(X_cat)

# %%
# standardize
#X_num = (X_num - X_num.mean())/X_num.std()

# %%
# put back together
X = pd.concat([X_num,X_cat], axis=1)
print(X.shape)
X.head()
# Out:
# (1556, 88)
#       DIFF_avg_KD  DIFF_avg_opp_KD  DIFF_avg_SIG_STR_pct  \
# 1090    -0.500000         0.000000              0.018281
# 1675     0.039062        -0.179688              0.457969
# 1477    -0.250000         0.000000             -0.170000
# 5581    -0.046875        -0.250000              0.003828
# 3083    -0.170415         0.246033             -0.144621
#
#       DIFF_avg_opp_SIG_STR_pct  DIFF_avg_TD_pct  DIFF_avg_opp_TD_pct  \
# 1090                  0.086250         0.612969            -0.224687
# 1675                 -0.132734         0.038242             0.582031
# 1477                 -0.210000        -0.250000            -0.212500
# 5581                  0.039766        -0.628750             0.086094
# 3083                 -0.014699         0.080573            -0.576428
#
#       DIFF_avg_SUB_ATT  DIFF_avg_opp_SUB_ATT  DIFF_avg_REV  DIFF_avg_opp_REV  \
# 1090         -0.359375              0.312500      0.312500          0.750000
# 1675          0.003906              0.632812      0.000000          0.000000
# 1477          0.000000              0.000000     -0.250000          0.000000
# 5581         -0.484375             -0.117188     -0.062500         -0.578125
# 3083          0.257807             -0.258451     -0.000994         -0.000011
#
#       ...  weight_class_WomenStrawweight  Fighters_Stance_Open Stance  \
# 1090  ...                              0                            0
# 1675  ...                              0                            0
# 1477  ...                              0                            0
# 5581  ...                              0                            0
# 3083  ...                              0                            0
#
#       Fighters_Stance_Orthodox  Fighters_Stance_Southpaw  \
# 1090                         0                         1
# 1675                         1                         0
# 1477                         1                         0
# 5581                         0                         1
# 3083                         1                         0
#
#       Fighters_Stance_Switch  Opponent_Stance_Open Stance  \
# 1090                       0                            0
# 1675                       0                            0
# 1477                       0                            0
# 5581                       0                            0
# 3083                       0                            0
#
#       Opponent_Stance_Orthodox  Opponent_Stance_Southpaw  \
# 1090                         0                         1
# 1675                         1                         0
# 1477                         1                         0
# 5581                         1                         0
# 3083                         1                         0
#
#       Opponent_Stance_Switch  title_bout
# 1090                       0       False
# 1675                       0       False
# 1477                       0       False
# 5581                       0       False
# 3083                       0       False
#
# [5 rows x 88 columns]

# %%
y.value_counts()
# Out:
# Loss    787
# Win     741
# Draw     28
# Name: Result, dtype: int64

# %%
# logistic regression
logr = LogisticRegression(random_state=0, max_iter=10000)
logr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=10000, random_state=0)

# %%
# Test score
print('Test R2:',logr.score(X,y).round(2))
# Out:
# Test R2: 0.58

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.model_selection import GridSearchCV

# %%
X_test = X
y_test = y

# %%
# LASSO to find insignificant features to drop
#grid = {'C':[0.01, 0.1, 1, 10, 100]}

#lr_model = LogisticRegression(penalty='l1', solver='liblinear',max_iter=10000)
#gs_model = GridSearchCV(estimator=lr_model, param_grid=grid,n_jobs=-1)
#gs_model.fit(X_train, y_train)
# TAKES ROUGHLY 6 MINUTES TO RUN!!!
# Out:
# GridSearchCV(estimator=LogisticRegression(max_iter=10000, penalty='l1',
#                                           solver='liblinear'),
#              n_jobs=-1, param_grid={'C': [0.01, 0.1, 1, 10, 100]})

# %%
#print(gs_model.classes_)
# Out:
# ['Draw' 'Loss' 'Win']

# %%
# plotting score for different C values
#results = pd.DataFrame()
#results['C'] = [0.01, 0.1, 1, 10, 100]
#print(gs_model.cv_results_)
#results['valid score'] = gs_model.cv_results_['mean_test_score']
# test doesn't mean test set; it means validation set

# plot results
#import matplotlib.pyplot as plt

#ax1 = results.plot.scatter(x='C',y='valid score')
#plt.xlabel('L1 Penalty Hyper Parameter')
#plt.ylabel('5-Fold Validation Score')
#plt.xscale('log')
# Out:
# {'mean_fit_time': array([ 6.15274458, 52.27362137, 76.36235752, 82.72856846, 94.98593054]), 'std_fit_time': array([ 2.80019831,  5.83905647,  5.43933543, 16.13424756, 31.19920308]), 'mean_score_time': array([0.08175006, 0.08267007, 0.03445015, 0.01624355, 0.01098104]), 'std_score_time': array([0.00129389, 0.00278858, 0.01193166, 0.00811428, 0.0010007 ]), 'param_C': masked_array(data=[0.01, 0.1, 1, 10, 100],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'C': 0.01}, {'C': 0.1}, {'C': 1}, {'C': 10}, {'C': 100}], 'split0_test_score': array([0.61204819, 0.61445783, 0.60883534, 0.6064257 , 0.60481928]), 'split1_test_score': array([0.58955823, 0.60883534, 0.60401606, 0.60562249, 0.60722892]), 'split2_test_score': array([0.60080321, 0.60803213, 0.61124498, 0.61124498, 0.61204819]), 'split3_test_score': array([0.60481928, 0.59116466, 0.57991968, 0.57670683, 0.57670683]), 'split4_test_score': array([0.61334405, 0.5988746 , 0.60048232, 0.60209003, 0.60128617]), 'mean_test_score': array([0.60411459, 0.60427291, 0.60089968, 0.60041801, 0.60041788]), 'std_test_score': array([0.00861945, 0.00824194, 0.01113595, 0.01220998, 0.01236119]), 'rank_test_score': array([2, 1, 3, 4, 5])}

# %%
#gs_model.best_estimator_
# Out:
# LogisticRegression(C=0.1, max_iter=10000, penalty='l1', solver='liblinear')

# %%
# Train a LR model with best parameters
model = LogisticRegression(C=0.1, penalty='l1', solver='liblinear')
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.1, penalty='l1', solver='liblinear')

# %%
# viewing coefficients after LASSO
print(model.classes_)
coef = model.coef_[2]
coef
# Out:
# ['Draw' 'Loss' 'Win']
# array([ 0.00000000e+00, -9.87117784e-03,  1.18759998e-01, -1.92693465e-01,
#         0.00000000e+00, -1.65794813e-01,  4.18334164e-02,  7.08288564e-03,
#        -1.66786460e-01,  1.84524666e-02,  1.98233181e-02, -1.59604314e-02,
#        -2.15630402e-03,  2.70772761e-04, -3.64581456e-02,  3.52466780e-02,
#         6.34967039e-03, -5.12260120e-03,  5.82595863e-02,  0.00000000e+00,
#         5.24631868e-02,  3.38918429e-02,  1.34156412e-02, -6.63613352e-03,
#        -3.03789016e-03,  5.42390601e-05,  0.00000000e+00,  0.00000000e+00,
#         9.19634293e-03, -1.73651970e-02,  4.04216049e-02, -4.31046755e-02,
#        -1.95859318e-02,  1.81293120e-02,  0.00000000e+00,  0.00000000e+00,
#        -3.43902036e-03,  7.09793603e-05,  1.36151069e-02, -2.14777278e-02,
#        -1.52559808e-02,  3.97321540e-03,  2.54063352e-02, -2.88983967e-02,
#         2.91263255e-03, -5.75787803e-03, -7.73158189e-04, -1.90419417e-03,
#         9.42019554e-04,  5.68842569e-03,  2.34300425e-02,  1.59900708e-02,
#         0.00000000e+00,  4.24273164e-02,  0.00000000e+00, -3.16087802e-02,
#         0.00000000e+00, -1.40883607e-01,  1.02760536e-02,  2.70560226e-03,
#         3.73794018e-02,  0.00000000e+00, -1.95295913e-02,  2.23135228e-02,
#         8.82200093e-03, -6.02618928e-02,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.76720130e-03,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -1.13914708e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         9.10192871e-02, -3.21121416e-02,  0.00000000e+00,  0.00000000e+00])

# %%
# storing coefficients and feature name in data frame
coef_df = pd.DataFrame()
coef_df['features'] = X_train.columns
coef_df['coefficient'] = coef
print(coef_df.shape)
print(coef_df.iloc[0,1])
coef_df.head()
# Out:
# (88, 2)
# 0.0
#                    features  coefficient
# 0               DIFF_avg_KD     0.000000
# 1           DIFF_avg_opp_KD    -0.009871
# 2      DIFF_avg_SIG_STR_pct     0.118760
# 3  DIFF_avg_opp_SIG_STR_pct    -0.192693
# 4           DIFF_avg_TD_pct     0.000000

# %%
# remove features with zero coefficients
coef_df = coef_df[coef_df['coefficient'] != 0]
coef_df = coef_df.sort_values(by=['coefficient'],ascending=False)

print(coef_df.shape)
coef_df.head()
# Out:
# (59, 2)
#                     features  coefficient
# 2       DIFF_avg_SIG_STR_pct     0.118760
# 84  Opponent_Stance_Orthodox     0.091019
# 18           DIFF_avg_TD_att     0.058260
# 20       DIFF_avg_opp_TD_att     0.052463
# 53   DIFF_longest_win_streak     0.042427

# %%
# plot coefficients
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
plt.bar('features', 'coefficient', data = coef_df, color = "blue")
plt.xlabel("Feature")
plt.xticks(rotation = 90)
plt.ylabel("Coefficient")
plt.title("Coefficients of Signficant Features from LASSO")
plt.show()

# %%
# removing insifnificant features from X
X_train_imp = X_train[coef_df.features]
X_test_imp = X_test[coef_df.features]
X_train_imp.head(3)
# Out:
#       DIFF_avg_SIG_STR_pct  Opponent_Stance_Orthodox  DIFF_avg_TD_att  \
# 6452              0.047500                         1         1.000000
# 5590              0.123125                         1         3.343750
# 4384              0.015449                         1       -16.173828
#
#       DIFF_avg_opp_TD_att  DIFF_longest_win_streak  DIFF_avg_SUB_ATT  \
# 6452             0.250000                       -2         -0.250000
# 5590            -5.187500                        1          0.187500
# 4384             0.037109                       -5         -0.015625
#
#       DIFF_avg_LEG_att  DIFF_win_by_Submission  DIFF_avg_TOTAL_STR_landed  \
# 6452        -14.250000                      -1                 -22.750000
# 5590          5.437500                       0                  45.187500
# 4384          1.234375                       0                -100.330078
#
#       DIFF_avg_opp_TD_landed  ...  DIFF_losses  Opponent_Stance_Southpaw  \
# 6452                0.250000  ...            1                         0
# 5590               -2.750000  ...           -3                         0
# 4384                0.679688  ...            0                         0
#
#       DIFF_avg_TOTAL_STTHEIR_att  DIFF_avg_LEG_landed  Diff_age  \
# 6452                  -56.250000           -10.000000        -6
# 5590                   33.468750             4.718750        -7
# 4384                 -160.742188            -0.578125         3
#
#       Fighters_Stance_Orthodox  DIFF_win_by_Decision_Split  \
# 6452                         0                          -1
# 5590                         1                           0
# 4384                         1                           0
#
#       DIFF_avg_opp_TD_pct  DIFF_avg_REV  DIFF_avg_opp_SIG_STR_pct
# 6452             0.125000           0.0                  0.255000
# 5590            -0.412500           0.0                 -0.014687
# 4384             0.726797           0.0                  0.150254
#
# [3 rows x 59 columns]

# %%
##X_train_imp.to_csv('LGRimpFeaturesOnlyUFC.csv')

# %%
# Rerunning Logistic Regression with reduced feature set
logr = LogisticRegression(random_state=0, max_iter=10000)
logr.fit(X_train_imp,y_train)
# Out:
# LogisticRegression(max_iter=10000, random_state=0)

# %%
print('Train R2:',logr.score(X_train_imp,y_train).round(2))
print('Test R2:',logr.score(X_test_imp,y_test).round(2))
# Out:
# Train R2: 0.62
# Test R2: 0.58

# %% [markdown]
# ## PCA Feature Selection

# %%
def biplot(X,n_comp,j1,j2,scale=1,alpha=0.25,s=50):
    
    import numpy as np
    import pandas as pd
    from sklearn.decomposition import PCA
    import matplotlib.pyplot as plt

    #X = (X-X.mean())/X.std()
    pca = PCA(n_components=n_comp)
    pca.fit(X)
    cols = ['PC-'+str(i+1) for i in range(n_comp)]
    Z = pca.transform(X)
    Z = pd.DataFrame(Z,columns=cols)
    Z.plot.scatter(x=j1-1,y=j2-1,
                   alpha=alpha,
                   s=s,
                   figsize=(10,10))
    sd = np.sqrt(pca.explained_variance_)
    Zj1 = sd[j1-1]*np.array([1,0])
    Zj2 = sd[j2-1]*np.array([0,1])
    plt.arrow(0,0,Zj1[0],Zj1[1],head_width=0.1,color='k')
    plt.arrow(0,0,Zj2[0],Zj2[1],head_width=0.1,color='k')

    L = pca.components_
    L = pd.DataFrame(L,index=cols,columns=X.columns)
    for k in range(X.shape[1]):
        x = scale*L.iloc[j1-1,k]
        y = scale*L.iloc[j2-1,k]
        plt.arrow(0,0,x,y,head_width=0.1,color='r')
        plt.text(1.2*x,1.2*y,X.columns[k],color='black')
        plt.xlim([-3,3])
        plt.ylim([-3,3])
        
    PVE = pca.explained_variance_ratio_
    PVE = pd.Series(PVE,index=cols)
    return PVE

# %%
biplot(X_train_imp,10,1,2,scale=4,alpha=.5,s=100)
# Out:
# PC-1     0.679243
# PC-2     0.147389
# PC-3     0.116505
# PC-4     0.024257
# PC-5     0.017928
# PC-6     0.002604
# PC-7     0.002533
# PC-8     0.001331
# PC-9     0.001219
# PC-10    0.001130
# dtype: float64

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
    
model = PCA(n_components=25).fit(X_train)
X_pc = model.transform(X_train)
print(X_pc)

# number of components
n_pcs= model.components_.shape[0]

# get the index of the most important feature on EACH component
# LIST COMPREHENSION HERE
most_important = [np.abs(model.components_[i]).argmax() for i in range(n_pcs)]
print(most_important)

initial_feature_names = X_train.columns
# get the names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]
print(most_important_names)

# LIST COMPREHENSION HERE AGAIN
dic = {'PC{}'.format(i): most_important_names[i] for i in range(n_pcs)}

# build the dataframe
df1 = pd.DataFrame(dic.items(), columns =['PC','Label'])
df1

# %%
PVE = model.explained_variance_ratio_
PVE = pd.Series(PVE)

PVEtop10 = PVE.sort_values(ascending=False)[:25]
df1['Value'] = PVEtop10
#.plot.barh()
df1

# %%
import matplotlib.pyplot as plt
Best10 = pd.Series(df1.Value,df1.Label)
plt.barh(df1.Label, df1.Value)

# %%
# removing insifnificant features from X

X_train_imp = X_train[df1.Label]
X_test_imp = X_test[df1.Label]

X_train_imp = X_train_imp.loc[:,~X_train_imp.columns.duplicated()]
X_test_imp = X_test_imp.loc[:,~X_test_imp.columns.duplicated()]

X_train_imp = (X_train_imp - X_train_imp.mean())/X_train_imp.std()
X_test_imp = (X_test_imp - X_test_imp.mean())/X_test_imp.std()


X_train_imp.head(3)
# Out:
#       DIFF_total_time_fought(seconds)  DIFF_avg_CTRL_time(seconds)  \
# 5582                        -0.204714                    -0.494729
# 6430                         0.237007                     0.864967
# 1448                         0.759943                    -0.654981
#
#       DIFF_avg_opp_CTRL_time(seconds)  DIFF_avg_opp_TOTAL_STTHEIR_att  \
# 5582                        -0.403083                        0.751780
# 6430                        -0.032668                        0.404993
# 1448                         1.775044                        0.475139
#
#       DIFF_avg_TOTAL_STR_landed  DIFF_avg_opp_TOTAL_STR_landed  \
# 5582                   0.225698                       0.259005
# 6430                   3.144048                       0.843773
# 1448                   1.661901                       0.574620
#
#       DIFF_avg_HEAD_att  DIFF_total_rounds_fought  \
# 5582           0.334728                 -0.730871
# 6430          -0.054542                 -0.118681
# 1448           0.117086                  0.309853
#
#       DIFF_avg_opp_DISTANCE_landed  DIFF_avg_opp_HEAD_landed  ...  \
# 5582                      1.065252                 -0.329204  ...
# 6430                     -0.025624                 -0.153085  ...
# 1448                      0.057096                 -0.014085  ...
#
#       DIFF_avg_GROUND_att  DIFF_Reach_cms  DIFF_Weight_lbs  DIFF_avg_BODY_att  \
# 5582            -0.534446        0.620124         1.451501           0.155703
# 6430             2.061994       -0.602348        -1.459358           2.092548
# 1448            -0.131389       -1.213584        -0.974215          -0.173353
#
#       DIFF_avg_opp_BODY_att  Diff_age  DIFF_Height_cms  DIFF_avg_TD_att  \
# 5582               1.887789 -0.385707         2.412574        -0.407908
# 6430              -0.104219 -1.154527        -1.201352        -0.131237
# 1448               0.596267  0.575318        -2.004446        -0.847327
#
#       DIFF_current_win_streak  DIFF_avg_DISTANCE_landed
# 5582                 0.436362                  1.375047
# 6430                -0.414622                 -0.020869
# 1448                -0.414622                  0.128161
#
# [3 rows x 21 columns]

# %%
logr = LogisticRegression(random_state=0, max_iter=10000)
logr.fit(X_train_imp,y_train)
print('Train R2:',logr.score(X_train_imp,y_train).round(3))
print('Test R2:',logr.score(X_test_imp,y_test).round(3))
# Out:
# Train R2: 0.599
# Test R2: 0.58

# %%
print(logr.classes_)
logr.coef_
# Out:
# ['Draw' 'Loss' 'Win']
# array([[-0.02446503,  0.02035565, -0.02500298, -0.06704396,  0.01729532,
#          0.13847589,  0.08303204,  0.03297495, -0.0401617 ,  0.01547324,
#         -0.00604666, -0.01184089,  0.00265614, -0.03066961, -0.00645092,
#          0.01640857, -0.01534756, -0.00641319, -0.01918927, -0.00536072,
#         -0.07629598],
#        [-0.13576054,  0.06298152,  0.06941461,  0.00896968,  0.11489009,
#         -0.00032074,  0.04158633, -0.05518262,  0.10313748,  0.03687937,
#         -0.04501849, -0.14251059, -0.0823245 , -0.03457595,  0.06275764,
#         -0.022969  ,  0.17993978,  0.04391672, -0.09837921, -0.05391111,
#         -0.18891435],
#        [ 0.16022557, -0.08333717, -0.04441163,  0.05807429, -0.1321854 ,
#         -0.13815515, -0.12461836,  0.02220768, -0.06297579, -0.05235261,
#          0.05106515,  0.15435148,  0.07966836,  0.06524555, -0.05630672,
#          0.00656042, -0.16459222, -0.03750353,  0.11756848,  0.05927183,
#          0.26521033]])

# %%
coef_df = pd.DataFrame()
coef_df['Features'] = X_train_imp.columns
coef_df['Coefficients'] = logr.coef_[2]
coef_df = coef_df.sort_values(by=['Coefficients'], ascending = False)
coef_df.head(21)
# Out:
#                            Features  Coefficients
# 20         DIFF_avg_DISTANCE_landed      0.265210
# 0   DIFF_total_time_fought(seconds)      0.160226
# 11              DIFF_avg_GROUND_att      0.154351
# 18                  DIFF_avg_TD_att      0.117568
# 12                   DIFF_Reach_cms      0.079668
# 13                  DIFF_Weight_lbs      0.065246
# 19          DIFF_current_win_streak      0.059272
# 3    DIFF_avg_opp_TOTAL_STTHEIR_att      0.058074
# 10              DIFF_avg_CLINCH_att      0.051065
# 7          DIFF_total_rounds_fought      0.022208
# 15            DIFF_avg_opp_BODY_att      0.006560
# 17                  DIFF_Height_cms     -0.037504
# 2   DIFF_avg_opp_CTRL_time(seconds)     -0.044412
# 9          DIFF_avg_opp_HEAD_landed     -0.052353
# 14                DIFF_avg_BODY_att     -0.056307
# 8      DIFF_avg_opp_DISTANCE_landed     -0.062976
# 1       DIFF_avg_CTRL_time(seconds)     -0.083337
# 6                 DIFF_avg_HEAD_att     -0.124618
# 4         DIFF_avg_TOTAL_STR_landed     -0.132185
# 5     DIFF_avg_opp_TOTAL_STR_landed     -0.138155
# 16                         Diff_age     -0.164592

# %% [markdown]
# ## Feature Engineering

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(2,interaction_only=False,include_bias=False)
Xe_train = poly.fit_transform(X_train_imp)
Xe_test = poly.fit_transform(X_test_imp)

cols = poly.get_feature_names(X_train_imp.columns)

Xe_train = pd.DataFrame(Xe_train,columns=cols)
Xe_test = pd.DataFrame(Xe_test,columns=cols)

print('             X shape =',X_train_imp.shape)
print('X (engineered) shape =',Xe_train.shape)
Xe_train.head(3)
# Out:
#              X shape = (6224, 21)
# X (engineered) shape = (6224, 252)
#    DIFF_total_time_fought(seconds)  DIFF_avg_CTRL_time(seconds)  \
# 0                        -0.204714                    -0.494729
# 1                         0.237007                     0.864967
# 2                         0.759943                    -0.654981
#
#    DIFF_avg_opp_CTRL_time(seconds)  DIFF_avg_opp_TOTAL_STTHEIR_att  \
# 0                        -0.403083                        0.751780
# 1                        -0.032668                        0.404993
# 2                         1.775044                        0.475139
#
#    DIFF_avg_TOTAL_STR_landed  DIFF_avg_opp_TOTAL_STR_landed  \
# 0                   0.225698                       0.259005
# 1                   3.144048                       0.843773
# 2                   1.661901                       0.574620
#
#    DIFF_avg_HEAD_att  DIFF_total_rounds_fought  DIFF_avg_opp_DISTANCE_landed  \
# 0           0.334728                 -0.730871                      1.065252
# 1          -0.054542                 -0.118681                     -0.025624
# 2           0.117086                  0.309853                      0.057096
#
#    DIFF_avg_opp_HEAD_landed  ...  DIFF_Height_cms^2  \
# 0                 -0.329204  ...           5.820514
# 1                 -0.153085  ...           1.443246
# 2                 -0.014085  ...           4.017805
#
#    DIFF_Height_cms DIFF_avg_TD_att  DIFF_Height_cms DIFF_current_win_streak  \
# 0                        -0.984108                                 1.052755
# 1                         0.157661                                 0.498107
# 2                         1.698422                                 0.831088
#
#    DIFF_Height_cms DIFF_avg_DISTANCE_landed  DIFF_avg_TD_att^2  \
# 0                                  3.317403           0.166389
# 1                                  0.025072           0.017223
# 2                                 -0.256891           0.717963
#
#    DIFF_avg_TD_att DIFF_current_win_streak  \
# 0                                -0.177996
# 1                                 0.054414
# 2                                 0.351321
#
#    DIFF_avg_TD_att DIFF_avg_DISTANCE_landed  DIFF_current_win_streak^2  \
# 0                                 -0.560893                   0.190412
# 1                                  0.002739                   0.171912
# 2                                 -0.108594                   0.171912
#
#    DIFF_current_win_streak DIFF_avg_DISTANCE_landed  \
# 0                                          0.600018
# 1                                          0.008653
# 2                                         -0.053138
#
#    DIFF_avg_DISTANCE_landed^2
# 0                    1.890754
# 1                    0.000436
# 2                    0.016425
#
# [3 rows x 252 columns]

# %%
Xe_train = (Xe_train - Xe_train.mean())/Xe_train.std()
Xe_test = (Xe_test - Xe_test.mean())/Xe_test.std()

# %%
# add bias column of ones
Xe_train['bias'] = 1
Xe_test['bias'] = 1

Xe_train.head(3)
# Out:
#    DIFF_total_time_fought(seconds)  DIFF_avg_CTRL_time(seconds)  \
# 0                        -0.204714                    -0.494729
# 1                         0.237007                     0.864967
# 2                         0.759943                    -0.654981
#
#    DIFF_avg_opp_CTRL_time(seconds)  DIFF_avg_opp_TOTAL_STTHEIR_att  \
# 0                        -0.403083                        0.751780
# 1                        -0.032668                        0.404993
# 2                         1.775044                        0.475139
#
#    DIFF_avg_TOTAL_STR_landed  DIFF_avg_opp_TOTAL_STR_landed  \
# 0                   0.225698                       0.259005
# 1                   3.144048                       0.843773
# 2                   1.661901                       0.574620
#
#    DIFF_avg_HEAD_att  DIFF_total_rounds_fought  DIFF_avg_opp_DISTANCE_landed  \
# 0           0.334728                 -0.730871                      1.065252
# 1          -0.054542                 -0.118681                     -0.025624
# 2           0.117086                  0.309853                      0.057096
#
#    DIFF_avg_opp_HEAD_landed  ...  DIFF_Height_cms DIFF_avg_TD_att  \
# 0                 -0.329204  ...                        -0.852998
# 1                 -0.153085  ...                         0.277758
# 2                 -0.014085  ...                         1.803657
#
#    DIFF_Height_cms DIFF_current_win_streak  \
# 0                                 1.049404
# 1                                 0.460812
# 2                                 0.814171
#
#    DIFF_Height_cms DIFF_avg_DISTANCE_landed  DIFF_avg_TD_att^2  \
# 0                                  3.219580          -0.434168
# 1                                  0.016090          -0.511873
# 2                                 -0.258264          -0.146837
#
#    DIFF_avg_TD_att DIFF_current_win_streak  \
# 0                                -0.230351
# 1                                 0.001415
# 2                                 0.297500
#
#    DIFF_avg_TD_att DIFF_avg_DISTANCE_landed  DIFF_current_win_streak^2  \
# 0                                 -0.591724                  -0.309784
# 1                                 -0.002008                  -0.316865
# 2                                 -0.118493                  -0.316865
#
#    DIFF_current_win_streak DIFF_avg_DISTANCE_landed  \
# 0                                          0.493729
# 1                                         -0.037255
# 2                                         -0.092737
#
#    DIFF_avg_DISTANCE_landed^2  bias
# 0                    0.423340     1
# 1                   -0.474891     1
# 2                   -0.467293     1
#
# [3 rows x 253 columns]

# %%
# cross-validation
logr = LogisticRegression(fit_intercept=False, max_iter = 10000)
logr.fit(Xe_train, y_train)
poly_train_score = logr.score(Xe_train, y_train)
poly_test_score = logr.score(Xe_test, y_test)
print('Train Score: ', poly_train_score.round(3))
print('Test Score: ', poly_test_score.round(3))
# Out:
# Train Score:  0.604
# Test Score:  0.54

# %% [markdown]
# ### PCA on Poly Features

# %%
model = PCA(n_components=25).fit(Xe_train)
Xe_pc = model.transform(Xe_train)

# number of components
n_pcs= model.components_.shape[0]

# get the index of the most important feature on EACH component
# LIST COMPREHENSION HERE
most_important = [np.abs(model.components_[i]).argmax() for i in range(n_pcs)]

initial_feature_names = Xe_train.columns
# get the names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]

# LIST COMPREHENSION HERE AGAIN
dic = {'PC{}'.format(i): most_important_names[i] for i in range(n_pcs)}

# build the dataframe
df1e = pd.DataFrame(dic.items(), columns =['PC','Label'])
df1e
# Out:
#       PC                                              Label
# 0    PC0  DIFF_avg_opp_TOTAL_STR_landed DIFF_avg_DISTANC...
# 1    PC1  DIFF_avg_CTRL_time(seconds) DIFF_avg_opp_TOTAL...
# 2    PC2     DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_Height_cms
# 3    PC3  DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_total_roun...
# 4    PC4  DIFF_avg_opp_CTRL_time(seconds) DIFF_avg_opp_T...
# 5    PC5              DIFF_avg_CLINCH_att DIFF_avg_BODY_att
# 6    PC6    DIFF_avg_CTRL_time(seconds) DIFF_avg_GROUND_att
# 7    PC7                     DIFF_avg_opp_TOTAL_STTHEIR_att
# 8    PC8     DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_Weight_lbs
# 9    PC9  DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_current_wi...
# 10  PC10       DIFF_avg_opp_DISTANCE_landed DIFF_avg_TD_att
# 11  PC11         DIFF_avg_CTRL_time(seconds) DIFF_Reach_cms
# 12  PC12                 DIFF_avg_TOTAL_STR_landed Diff_age
# 13  PC13             DIFF_avg_opp_TOTAL_STR_landed Diff_age
# 14  PC14  DIFF_avg_CTRL_time(seconds) DIFF_current_win_s...
# 15  PC15                            DIFF_avg_opp_BODY_att^2
# 16  PC16              DIFF_avg_HEAD_att DIFF_avg_GROUND_att
# 17  PC17                              DIFF_avg_CLINCH_att^2
# 18  PC18        DIFF_avg_CTRL_time(seconds) DIFF_Weight_lbs
# 19  PC19    DIFF_avg_opp_CTRL_time(seconds) DIFF_Height_cms
# 20  PC20                     DIFF_Reach_cms DIFF_Height_cms
# 21  PC21                  DIFF_avg_opp_CTRL_time(seconds)^2
# 22  PC22                        DIFF_avg_CTRL_time(seconds)
# 23  PC23                        DIFF_avg_CTRL_time(seconds)
# 24  PC24                        DIFF_avg_CTRL_time(seconds)

# %%
PVE = model.explained_variance_ratio_
PVE = pd.Series(PVE)

PVEtop10 = PVE.sort_values(ascending=False)[:25]
df1e['Value'] = PVEtop10
#.plot.barh()
df1e
# Out:
#       PC                                              Label     Value
# 0    PC0  DIFF_avg_opp_TOTAL_STR_landed DIFF_avg_DISTANC...  0.126240
# 1    PC1  DIFF_avg_CTRL_time(seconds) DIFF_avg_opp_TOTAL...  0.058375
# 2    PC2     DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_Height_cms  0.051824
# 3    PC3  DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_total_roun...  0.037950
# 4    PC4  DIFF_avg_opp_CTRL_time(seconds) DIFF_avg_opp_T...  0.031668
# 5    PC5              DIFF_avg_CLINCH_att DIFF_avg_BODY_att  0.028463
# 6    PC6    DIFF_avg_CTRL_time(seconds) DIFF_avg_GROUND_att  0.027655
# 7    PC7                     DIFF_avg_opp_TOTAL_STTHEIR_att  0.026721
# 8    PC8     DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_Weight_lbs  0.025079
# 9    PC9  DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_current_wi...  0.024569
# 10  PC10       DIFF_avg_opp_DISTANCE_landed DIFF_avg_TD_att  0.020508
# 11  PC11         DIFF_avg_CTRL_time(seconds) DIFF_Reach_cms  0.017898
# 12  PC12                 DIFF_avg_TOTAL_STR_landed Diff_age  0.015751
# 13  PC13             DIFF_avg_opp_TOTAL_STR_landed Diff_age  0.015509
# 14  PC14  DIFF_avg_CTRL_time(seconds) DIFF_current_win_s...  0.014384
# 15  PC15                            DIFF_avg_opp_BODY_att^2  0.013495
# 16  PC16              DIFF_avg_HEAD_att DIFF_avg_GROUND_att  0.013203
# 17  PC17                              DIFF_avg_CLINCH_att^2  0.012220
# 18  PC18        DIFF_avg_CTRL_time(seconds) DIFF_Weight_lbs  0.011790
# 19  PC19    DIFF_avg_opp_CTRL_time(seconds) DIFF_Height_cms  0.011152
# 20  PC20                     DIFF_Reach_cms DIFF_Height_cms  0.011060
# 21  PC21                  DIFF_avg_opp_CTRL_time(seconds)^2  0.010536
# 22  PC22                        DIFF_avg_CTRL_time(seconds)  0.010080
# 23  PC23                        DIFF_avg_CTRL_time(seconds)  0.009896
# 24  PC24                        DIFF_avg_CTRL_time(seconds)  0.009569

# %%
Best10 = pd.Series(df1e.Value,df1e.Label)
plt.barh(df1e.Label, df1e.Value)
# Out:
# <BarContainer object of 25 artists>

# %%
# removing insifnificant features from X

Xe_train = Xe_train[df1e.Label]
Xe_test = Xe_test[df1e.Label]

Xe_train = Xe_train.loc[:,~Xe_train.columns.duplicated()]
Xe_test = Xe_test.loc[:,~Xe_test.columns.duplicated()]

Xe_train = (Xe_train - Xe_train.mean())/Xe_train.std()
Xe_test = (Xe_test - Xe_test.mean())/Xe_test.std()


Xe_train.head(3)
# Out:
#    DIFF_avg_opp_TOTAL_STR_landed DIFF_avg_DISTANCE_landed  \
# 0                                          -0.068732
# 1                                          -0.379848
# 2                                          -0.303888
#
#    DIFF_avg_CTRL_time(seconds) DIFF_avg_opp_TOTAL_STTHEIR_att  \
# 0                                          -0.426117
# 1                                           0.324061
# 2                                          -0.363048
#
#    DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_Height_cms  \
# 0                                        1.917121
# 1                                       -0.394909
# 2                                       -0.863144
#
#    DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_total_rounds_fought  \
# 0                                          -0.725079
# 1                                          -0.258516
# 2                                          -0.076792
#
#    DIFF_avg_opp_CTRL_time(seconds) DIFF_avg_opp_TOTAL_STTHEIR_att  \
# 0                                          -0.511744
# 1                                          -0.254889
# 2                                           0.504351
#
#    DIFF_avg_CLINCH_att DIFF_avg_BODY_att  \
# 0                              -0.486036
# 1                              -1.092027
# 2                              -0.336219
#
#    DIFF_avg_CTRL_time(seconds) DIFF_avg_GROUND_att  \
# 0                                        -0.193777
# 1                                         0.724300
# 2                                        -0.301559
#
#    DIFF_avg_opp_TOTAL_STTHEIR_att  \
# 0                        0.751780
# 1                        0.404993
# 2                        0.475139
#
#    DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_Weight_lbs  \
# 0                                        1.199050
# 1                                       -0.571123
# 2                                       -0.436283
#
#    DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_current_win_streak  ...  \
# 0                                           0.280707       ...
# 1                                          -0.175840       ...
# 2                                          -0.202613       ...
#
#    DIFF_avg_opp_TOTAL_STR_landed Diff_age  \
# 0                               -0.165084
# 1                               -1.037896
# 2                                0.264693
#
#    DIFF_avg_CTRL_time(seconds) DIFF_current_win_streak  \
# 0                                          -0.220615
# 1                                          -0.339596
# 2                                           0.185662
#
#    DIFF_avg_opp_BODY_att^2  DIFF_avg_HEAD_att DIFF_avg_GROUND_att  \
# 0                 1.277285                              -0.261289
# 1                -0.492688                              -0.198454
# 2                -0.320979                              -0.106621
#
#    DIFF_avg_CLINCH_att^2  DIFF_avg_CTRL_time(seconds) DIFF_Weight_lbs  \
# 0               0.521680                                    -0.697758
# 1              -0.260609                                    -1.219897
# 2              -0.370141                                     0.603464
#
#    DIFF_avg_opp_CTRL_time(seconds) DIFF_Height_cms  \
# 0                                        -0.985984
# 1                                        -0.018353
# 2                                        -3.458840
#
#    DIFF_Reach_cms DIFF_Height_cms  DIFF_avg_opp_CTRL_time(seconds)^2  \
# 0                        0.660295                          -0.445119
# 1                        0.067744                          -0.530919
# 2                        1.378656                           1.143381
#
#    DIFF_avg_CTRL_time(seconds)
# 0                    -0.494729
# 1                     0.864967
# 2                    -0.654981
#
# [3 rows x 23 columns]

# %%
logr = LogisticRegression(random_state=0, max_iter=10000)
logr.fit(Xe_train,y_train)
print('Train R2:',logr.score(Xe_train,y_train).round(3))
print('Test R2:',logr.score(Xe_test,y_test).round(3))
# Out:
# Train R2: 0.517
# Test R2: 0.539

# %%
coef_df = pd.DataFrame()
coef_df['Features'] = Xe_train.columns
coef_df['Coefficients'] = logr.coef_[2]
coef_df = coef_df.sort_values(by=['Coefficients'], ascending = False)
coef_df.head(21)
# Out:
#                                              Features  Coefficients
# 17                              DIFF_avg_CLINCH_att^2      0.229650
# 6     DIFF_avg_CTRL_time(seconds) DIFF_avg_GROUND_att      0.152642
# 21                  DIFF_avg_opp_CTRL_time(seconds)^2      0.115354
# 19    DIFF_avg_opp_CTRL_time(seconds) DIFF_Height_cms      0.095587
# 13             DIFF_avg_opp_TOTAL_STR_landed Diff_age      0.091826
# 8      DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_Weight_lbs      0.080093
# 22                        DIFF_avg_CTRL_time(seconds)      0.049792
# 10       DIFF_avg_opp_DISTANCE_landed DIFF_avg_TD_att      0.044774
# 9   DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_current_wi...      0.036648
# 4   DIFF_avg_opp_CTRL_time(seconds) DIFF_avg_opp_T...      0.027512
# 12                 DIFF_avg_TOTAL_STR_landed Diff_age      0.017677
# 15                            DIFF_avg_opp_BODY_att^2      0.010371
# 11         DIFF_avg_CTRL_time(seconds) DIFF_Reach_cms     -0.006949
# 0   DIFF_avg_opp_TOTAL_STR_landed DIFF_avg_DISTANC...     -0.009371
# 1   DIFF_avg_CTRL_time(seconds) DIFF_avg_opp_TOTAL...     -0.010946
# 20                     DIFF_Reach_cms DIFF_Height_cms     -0.013424
# 18        DIFF_avg_CTRL_time(seconds) DIFF_Weight_lbs     -0.021846
# 2      DIFF_avg_opp_TOTAL_STTHEIR_att DIFF_Height_cms     -0.027008
# 16              DIFF_avg_HEAD_att DIFF_avg_GROUND_att     -0.028147
# 7                      DIFF_avg_opp_TOTAL_STTHEIR_att     -0.039093
# 14  DIFF_avg_CTRL_time(seconds) DIFF_current_win_s...     -0.043549

# %% [markdown]
# ## Confusion Matrix
